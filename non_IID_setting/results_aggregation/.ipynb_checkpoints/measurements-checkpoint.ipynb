# %%
import numpy
import pandas as pd

columns=['dataset', 'skew_type', 'skew', 'nr_clients', 'lr',  'mom',  'experiment_type']   
plotdf = pd.DataFrame(columns=columns)

# %%
#params set
datasets = ["mnist","cifar10","svhn_cropped", "emnist"]
skewtypes =['qty_skew','label_skew','feature_skew']
clientNum=[10,20]
for dataset in datasets:
    for skewtype in skewtypes:
        for clients in clientNum:
            if skewtype=='qty_skew':
                skewParams=[0.1,0.4,1.0,2.0]
            if skewtype=='label_skew':
                skewParams=[0.1,1.0,5.0]
            if skewtype=='feature_skew':
                skewParams=[0.1,0.02]
            for skewParam in skewParams:
                print(skewParam)
                fileToRead = 'clustering/experiments/extended_data/'+dataset+'_'+skewtype+'_'+str(skewParam)+'_'+str(clients)+'clients'+'.csv'
                print(fileToRead)

                df = pd.read_csv(fileToRead)
    #             first get the ground truth
                plotdf.loc[len(plotdf)] = [dataset, skewtype, skewParam, clients, df.loc[0,"server_lr"],  df.loc[0,"server_mom"], 'Ground Truth']  
                df = df.sort_values(by=['accuracy'])

                #eliminate fed grid one
                allClients = df.loc[(df['clientID'] >= 0)]
                allClients
                lr = allClients.loc[:,"client_lr"]
                momentum = allClients.loc[:,"client_mom"]
                accuracy = allClients.loc[:,"accuracy"]
                #median,mean, trimmed mean with all client HP results

                meanLR = numpy.mean(lr)
                medianLR = numpy.median(lr)

                meanMom = numpy.mean(momentum)
                medianMom = numpy.median(momentum)

                #trimmed mean
                trimBeta = 0.1

                #trim by value
                lr=numpy.sort(lr)
                mom=numpy.sort(momentum)
                size = len(lr)
                trim = size*trimBeta
                trim

                lrTrimmed = lr[int(trim):int(size)-int(trim)]
                momTrimmed = mom[int(trim):int(size)-int(trim)]

                meanLRTrim = numpy.mean(lrTrimmed)
                meanMomTrim = numpy.mean(momTrimmed)

                print("mean lr=", meanLR)
                print("median lr=", medianLR)
                print("trimmed mean with beta=0.1 lr=", meanLRTrim)

                print("mean momentum=", meanMom)
                print("median momentum=", medianMom)
                print("trimmed mean with beta=0.1 momentum=", meanMomTrim)
                plotdf.loc[len(plotdf)] = [dataset, skewtype, skewParam, clients, meanLR,  meanMom, 'mean']  
                plotdf.loc[len(plotdf)] = [dataset, skewtype, skewParam, clients, meanLRTrim,  meanMomTrim, 'trimmed mean']
                plotdf.loc[len(plotdf)] = [dataset, skewtype, skewParam, clients, medianLR,  medianMom, 'median']
                #mean, median, average with best client HP results wrt accuracy
                lrFinal = []
                momFinal = list()
                fraction = 0.05 #top 5 percent records per client
                for i in range(1,clients+1):
                    clientNow=allClients.loc[allClients['clientID'] == i]
                    sortedClient = clientNow.sort_values(by=['accuracy'])
                    size = len(sortedClient)
                    top = int(size*fraction)
                    lr = sortedClient.loc[:,"client_lr"]
                    mom = sortedClient.loc[:,"client_mom"]
                    lrTrimmed = (lr[int(size)-int(top):int(size)]).values.tolist()
                    momTrimmed = (mom[int(size)-int(top):int(size)]).values.tolist()
                    lrFinal = lrFinal+lrTrimmed
                    momFinal = momFinal+momTrimmed

                meanLR = numpy.mean(lrFinal)
                medianLR = numpy.median(lrFinal)

                meanMom = numpy.mean(momFinal)
                medianMom = numpy.median(momFinal)   
                print("mean lr with top 5 percent per client=", meanLR)
                print("median lr with top 5 percent per client=", medianLR)

                print("mean momentum with top 5 percent per client=", meanMom)
                print("median momentum with top 5 percent per client=", medianMom)

                plotdf.loc[len(plotdf)] = [dataset, skewtype, skewParam, clients, meanLR,  meanMom, 'mean of the top 5%']  
                plotdf.loc[len(plotdf)] = [dataset, skewtype, skewParam, clients, medianLR,  medianMom, 'median of the top 5%']
# Out:
# 0.1
# clustering/experiments/extended_data/mnist_qty_skew_0.1_10clients.csv
# mean lr= 0.15142857142857144
# median lr= 0.07
# trimmed mean with beta=0.1 lr= 0.12553571428571428
# mean momentum= 0.55
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.56875
# mean lr with top 5 percent per client= 0.32799999999999996
# median lr with top 5 percent per client= 0.3
# mean momentum with top 5 percent per client= 0.813
# median momentum with top 5 percent per client= 0.9
# 0.4
# clustering/experiments/extended_data/mnist_qty_skew_0.4_10clients.csv
# mean lr= 0.15142857142857144
# median lr= 0.07
# trimmed mean with beta=0.1 lr= 0.12553571428571425
# mean momentum= 0.55
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.5687499999999999
# mean lr with top 5 percent per client= 0.3585
# median lr with top 5 percent per client= 0.4
# mean momentum with top 5 percent per client= 0.8925000000000001
# median momentum with top 5 percent per client= 0.95
# 1.0
# clustering/experiments/extended_data/mnist_qty_skew_1.0_10clients.csv
# mean lr= 0.15142857142857144
# median lr= 0.07
# trimmed mean with beta=0.1 lr= 0.12570673712021135
# mean momentum= 0.55
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.5686261558784677
# mean lr with top 5 percent per client= 0.33311111111111114
# median lr with top 5 percent per client= 0.3
# mean momentum with top 5 percent per client= 0.9188888888888891
# median momentum with top 5 percent per client= 0.95
# 2.0
# clustering/experiments/extended_data/mnist_qty_skew_2.0_10clients.csv
# mean lr= 0.15142857142857144
# median lr= 0.07
# trimmed mean with beta=0.1 lr= 0.12570673712021135
# mean momentum= 0.55
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.5686261558784677
# mean lr with top 5 percent per client= 0.37044444444444447
# median lr with top 5 percent per client= 0.5
# mean momentum with top 5 percent per client= 0.9211111111111112
# median momentum with top 5 percent per client= 0.95
# 0.1
# clustering/experiments/extended_data/mnist_qty_skew_0.1_20clients.csv
# mean lr= 0.15142857142857144
# median lr= 0.07
# trimmed mean with beta=0.1 lr= 0.12553571428571425
# mean momentum= 0.55
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.5687500000000001
# mean lr with top 5 percent per client= 0.32787499999999997
# median lr with top 5 percent per client= 0.3
# mean momentum with top 5 percent per client= 0.880625
# median momentum with top 5 percent per client= 0.9
# 0.4
# clustering/experiments/extended_data/mnist_qty_skew_0.4_20clients.csv
# mean lr= 0.15142857142857144
# median lr= 0.07
# trimmed mean with beta=0.1 lr= 0.12553571428571428
# mean momentum= 0.55
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.56875
# mean lr with top 5 percent per client= 0.343
# median lr with top 5 percent per client= 0.3
# mean momentum with top 5 percent per client= 0.885
# median momentum with top 5 percent per client= 0.925
# 1.0
# clustering/experiments/extended_data/mnist_qty_skew_1.0_20clients.csv
# mean lr= 0.15142857142857144
# median lr= 0.07
# trimmed mean with beta=0.1 lr= 0.12562631210636807
# mean momentum= 0.5499999999999999
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.5686843946815955
# mean lr with top 5 percent per client= 0.3691764705882353
# median lr with top 5 percent per client= 0.5
# mean momentum with top 5 percent per client= 0.9188235294117648
# median momentum with top 5 percent per client= 0.95
# 2.0
# clustering/experiments/extended_data/mnist_qty_skew_2.0_20clients.csv
# mean lr= 0.1514285714285714
# median lr= 0.07
# trimmed mean with beta=0.1 lr= 0.12553571428571428
# mean momentum= 0.55
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.56875
# mean lr with top 5 percent per client= 0.358
# median lr with top 5 percent per client= 0.3
# mean momentum with top 5 percent per client= 0.9227777777777779
# median momentum with top 5 percent per client= 0.95
# 0.1
# clustering/experiments/extended_data/mnist_label_skew_0.1_10clients.csv
# mean lr= 0.14375
# median lr= 0.08
# trimmed mean with beta=0.1 lr= 0.1159375
# mean momentum= 0.55
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.56875
# mean lr with top 5 percent per client= 0.2725
# median lr with top 5 percent per client= 0.3
# mean momentum with top 5 percent per client= 0.89875
# median momentum with top 5 percent per client= 0.9
# 1.0
# clustering/experiments/extended_data/mnist_label_skew_1.0_10clients.csv
# mean lr= 0.14375
# median lr= 0.08
# trimmed mean with beta=0.1 lr= 0.1159375
# mean momentum= 0.5499999999999999
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.56875
# mean lr with top 5 percent per client= 0.301
# median lr with top 5 percent per client= 0.3
# mean momentum with top 5 percent per client= 0.9274999999999999
# median momentum with top 5 percent per client= 0.95
# 5.0
# clustering/experiments/extended_data/mnist_label_skew_5.0_10clients.csv
# mean lr= 0.14375
# median lr= 0.08
# trimmed mean with beta=0.1 lr= 0.1159375
# mean momentum= 0.5499999999999999
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.56875
# mean lr with top 5 percent per client= 0.31225
# median lr with top 5 percent per client= 0.3
# mean momentum with top 5 percent per client= 0.9087500000000001
# median momentum with top 5 percent per client= 0.9
# 0.1
# clustering/experiments/extended_data/mnist_label_skew_0.1_20clients.csv
# mean lr= 0.14375
# median lr= 0.08
# trimmed mean with beta=0.1 lr= 0.1159375
# mean momentum= 0.55
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.56875
# mean lr with top 5 percent per client= 0.32825
# median lr with top 5 percent per client= 0.3
# mean momentum with top 5 percent per client= 0.809375
# median momentum with top 5 percent per client= 0.9
# 1.0
# clustering/experiments/extended_data/mnist_label_skew_1.0_20clients.csv
# mean lr= 0.14375
# median lr= 0.08
# trimmed mean with beta=0.1 lr= 0.1159375
# mean momentum= 0.55
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.56875
# mean lr with top 5 percent per client= 0.3465
# median lr with top 5 percent per client= 0.3
# mean momentum with top 5 percent per client= 0.9287500000000002
# median momentum with top 5 percent per client= 0.95
# 5.0
# clustering/experiments/extended_data/mnist_label_skew_5.0_20clients.csv
# mean lr= 0.14375
# median lr= 0.08
# trimmed mean with beta=0.1 lr= 0.1159375
# mean momentum= 0.5499999999999999
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.56875
# mean lr with top 5 percent per client= 0.33762499999999995
# median lr with top 5 percent per client= 0.3
# mean momentum with top 5 percent per client= 0.9162500000000001
# median momentum with top 5 percent per client= 0.95
# 0.1
# clustering/experiments/extended_data/mnist_feature_skew_0.1_10clients.csv
# mean lr= 0.14375
# median lr= 0.08
# trimmed mean with beta=0.1 lr= 0.1159375
# mean momentum= 0.55
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.56875
# mean lr with top 5 percent per client= 0.33775
# median lr with top 5 percent per client= 0.3
# mean momentum with top 5 percent per client= 0.91375
# median momentum with top 5 percent per client= 0.9
# 0.02
# clustering/experiments/extended_data/mnist_feature_skew_0.02_10clients.csv
# mean lr= 0.14375
# median lr= 0.08
# trimmed mean with beta=0.1 lr= 0.1159375
# mean momentum= 0.5499999999999999
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.56875
# mean lr with top 5 percent per client= 0.322
# median lr with top 5 percent per client= 0.3
# mean momentum with top 5 percent per client= 0.9100000000000001
# median momentum with top 5 percent per client= 0.925
# 0.1
# clustering/experiments/extended_data/mnist_feature_skew_0.1_20clients.csv
# mean lr= 0.14375000000000002
# median lr= 0.08
# trimmed mean with beta=0.1 lr= 0.1159375
# mean momentum= 0.55
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.56875
# mean lr with top 5 percent per client= 0.31775
# median lr with top 5 percent per client= 0.3
# mean momentum with top 5 percent per client= 0.923125
# median momentum with top 5 percent per client= 0.95
# 0.02
# clustering/experiments/extended_data/mnist_feature_skew_0.02_20clients.csv
# mean lr= 0.14375
# median lr= 0.08
# trimmed mean with beta=0.1 lr= 0.1159375
# mean momentum= 0.55
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.56875
# mean lr with top 5 percent per client= 0.332375
# median lr with top 5 percent per client= 0.3
# mean momentum with top 5 percent per client= 0.9137500000000001
# median momentum with top 5 percent per client= 0.925
# 0.1
# clustering/experiments/extended_data/cifar10_qty_skew_0.1_10clients.csv
# mean lr= 0.15395348837209305
# median lr= 0.07
# trimmed mean with beta=0.1 lr= 0.12869186046511627
# mean momentum= 0.5313953488372093
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.5454941860465117
# mean lr with top 5 percent per client= 0.2678333333333333
# median lr with top 5 percent per client= 0.3
# mean momentum with top 5 percent per client= 0.6825
# median momentum with top 5 percent per client= 0.9
# 0.4
# clustering/experiments/extended_data/cifar10_qty_skew_0.4_10clients.csv
# mean lr= 0.15395348837209305
# median lr= 0.07
# trimmed mean with beta=0.1 lr= 0.12869186046511627
# mean momentum= 0.5313953488372092
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.5454941860465117
# mean lr with top 5 percent per client= 0.24333333333333335
# median lr with top 5 percent per client= 0.1
# mean momentum with top 5 percent per client= 0.6958333333333333
# median momentum with top 5 percent per client= 0.9
# 1.0
# clustering/experiments/extended_data/cifar10_qty_skew_1.0_10clients.csv
# mean lr= 0.15395348837209305
# median lr= 0.07
# trimmed mean with beta=0.1 lr= 0.12869186046511627
# mean momentum= 0.5313953488372093
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.5454941860465117
# mean lr with top 5 percent per client= 0.23033333333333333
# median lr with top 5 percent per client= 0.1
# mean momentum with top 5 percent per client= 0.7433333333333335
# median momentum with top 5 percent per client= 0.9
# 2.0
# clustering/experiments/extended_data/cifar10_qty_skew_2.0_10clients.csv
# mean lr= 0.15395348837209305
# median lr= 0.07
# trimmed mean with beta=0.1 lr= 0.12869186046511627
# mean momentum= 0.5313953488372093
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.5454941860465117
# mean lr with top 5 percent per client= 0.25400000000000006
# median lr with top 5 percent per client= 0.3
# mean momentum with top 5 percent per client= 0.7508333333333332
# median momentum with top 5 percent per client= 0.9
# 0.1
# clustering/experiments/extended_data/cifar10_qty_skew_0.1_20clients.csv
# mean lr= 0.15395348837209305
# median lr= 0.07
# trimmed mean with beta=0.1 lr= 0.12869186046511627
# mean momentum= 0.5313953488372093
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.5454941860465117
# mean lr with top 5 percent per client= 0.2155
# median lr with top 5 percent per client= 0.1
# mean momentum with top 5 percent per client= 0.6466666666666666
# median momentum with top 5 percent per client= 0.9
# 0.4
# clustering/experiments/extended_data/cifar10_qty_skew_0.4_20clients.csv
# mean lr= 0.15395348837209305
# median lr= 0.07
# trimmed mean with beta=0.1 lr= 0.12869186046511627
# mean momentum= 0.5313953488372093
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.5454941860465117
# mean lr with top 5 percent per client= 0.285
# median lr with top 5 percent per client= 0.3
# mean momentum with top 5 percent per client= 0.6445833333333333
# median momentum with top 5 percent per client= 0.6
# 1.0
# clustering/experiments/extended_data/cifar10_qty_skew_1.0_20clients.csv
# mean lr= 0.15395348837209305
# median lr= 0.07
# trimmed mean with beta=0.1 lr= 0.12869186046511627
# mean momentum= 0.5313953488372093
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.5454941860465117
# mean lr with top 5 percent per client= 0.25116666666666665
# median lr with top 5 percent per client= 0.3
# mean momentum with top 5 percent per client= 0.6770833333333334
# median momentum with top 5 percent per client= 0.9
# 2.0
# clustering/experiments/extended_data/cifar10_qty_skew_2.0_20clients.csv
# mean lr= 0.15395348837209305
# median lr= 0.07
# trimmed mean with beta=0.1 lr= 0.12869186046511627
# mean momentum= 0.5313953488372093
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.5454941860465117
# mean lr with top 5 percent per client= 0.2736666666666666
# median lr with top 5 percent per client= 0.3
# mean momentum with top 5 percent per client= 0.67125
# median momentum with top 5 percent per client= 0.9
# 0.1
# clustering/experiments/extended_data/cifar10_label_skew_0.1_10clients.csv
# mean lr= 0.14375
# median lr= 0.08
# trimmed mean with beta=0.1 lr= 0.1159375
# mean momentum= 0.55
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.56875
# mean lr with top 5 percent per client= 0.3355
# median lr with top 5 percent per client= 0.3
# mean momentum with top 5 percent per client= 0.55
# median momentum with top 5 percent per client= 0.6
# 1.0
# clustering/experiments/extended_data/cifar10_label_skew_1.0_10clients.csv
# mean lr= 0.14375
# median lr= 0.08
# trimmed mean with beta=0.1 lr= 0.1159375
# mean momentum= 0.55
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.56875
# mean lr with top 5 percent per client= 0.23399999999999999
# median lr with top 5 percent per client= 0.1
# mean momentum with top 5 percent per client= 0.8099999999999999
# median momentum with top 5 percent per client= 0.9
# 5.0
# clustering/experiments/extended_data/cifar10_label_skew_5.0_10clients.csv
# mean lr= 0.14375000000000002
# median lr= 0.08
# trimmed mean with beta=0.1 lr= 0.1159375
# mean momentum= 0.55
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.56875
# mean lr with top 5 percent per client= 0.2205
# median lr with top 5 percent per client= 0.1
# mean momentum with top 5 percent per client= 0.82
# median momentum with top 5 percent per client= 0.9
# 0.1
# clustering/experiments/extended_data/cifar10_label_skew_0.1_20clients.csv
# mean lr= 0.14375000000000002
# median lr= 0.08
# trimmed mean with beta=0.1 lr= 0.1159375
# mean momentum= 0.55
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.56875
# mean lr with top 5 percent per client= 0.19412500000000002
# median lr with top 5 percent per client= 0.09
# mean momentum with top 5 percent per client= 0.6775
# median momentum with top 5 percent per client= 0.9
# 1.0
# clustering/experiments/extended_data/cifar10_label_skew_1.0_20clients.csv
# mean lr= 0.14375
# median lr= 0.08
# trimmed mean with beta=0.1 lr= 0.1159375
# mean momentum= 0.55
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.56875
# mean lr with top 5 percent per client= 0.218625
# median lr with top 5 percent per client= 0.1
# mean momentum with top 5 percent per client= 0.806875
# median momentum with top 5 percent per client= 0.9
# 5.0
# clustering/experiments/extended_data/cifar10_label_skew_5.0_20clients.csv
# mean lr= 0.14375000000000002
# median lr= 0.08
# trimmed mean with beta=0.1 lr= 0.1159375
# mean momentum= 0.55
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.56875
# mean lr with top 5 percent per client= 0.23325
# median lr with top 5 percent per client= 0.1
# mean momentum with top 5 percent per client= 0.8
# median momentum with top 5 percent per client= 0.9
# 0.1
# clustering/experiments/extended_data/cifar10_feature_skew_0.1_10clients.csv
# mean lr= 0.14375
# median lr= 0.08
# trimmed mean with beta=0.1 lr= 0.1159375
# mean momentum= 0.55
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.56875
# mean lr with top 5 percent per client= 0.22824999999999998
# median lr with top 5 percent per client= 0.1
# mean momentum with top 5 percent per client= 0.8324999999999999
# median momentum with top 5 percent per client= 0.9
# 0.02
# clustering/experiments/extended_data/cifar10_feature_skew_0.02_10clients.csv
# mean lr= 0.14375
# median lr= 0.08
# trimmed mean with beta=0.1 lr= 0.1159375
# mean momentum= 0.55
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.56875
# mean lr with top 5 percent per client= 0.2615
# median lr with top 5 percent per client= 0.2
# mean momentum with top 5 percent per client= 0.7874999999999999
# median momentum with top 5 percent per client= 0.9
# 0.1
# clustering/experiments/extended_data/cifar10_feature_skew_0.1_20clients.csv
# mean lr= 0.14375
# median lr= 0.08
# trimmed mean with beta=0.1 lr= 0.1159375
# mean momentum= 0.55
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.56875
# mean lr with top 5 percent per client= 0.228375
# median lr with top 5 percent per client= 0.1
# mean momentum with top 5 percent per client= 0.77625
# median momentum with top 5 percent per client= 0.9
# 0.02
# clustering/experiments/extended_data/cifar10_feature_skew_0.02_20clients.csv
# mean lr= 0.14375
# median lr= 0.08
# trimmed mean with beta=0.1 lr= 0.1159375
# mean momentum= 0.55
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.56875
# mean lr with top 5 percent per client= 0.26412500000000005
# median lr with top 5 percent per client= 0.3
# mean momentum with top 5 percent per client= 0.7625
# median momentum with top 5 percent per client= 0.9
# 0.1
# clustering/experiments/extended_data/svhn_cropped_qty_skew_0.1_10clients.csv
# mean lr= 0.15142857142857144
# median lr= 0.07
# trimmed mean with beta=0.1 lr= 0.12553571428571428
# mean momentum= 0.55
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.56875
# mean lr with top 5 percent per client= 0.24340000000000003
# median lr with top 5 percent per client= 0.3
# mean momentum with top 5 percent per client= 0.612
# median momentum with top 5 percent per client= 0.6
# 0.4
# clustering/experiments/extended_data/svhn_cropped_qty_skew_0.4_10clients.csv
# mean lr= 0.15142857142857144
# median lr= 0.07
# trimmed mean with beta=0.1 lr= 0.12553571428571428
# mean momentum= 0.55
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.56875
# mean lr with top 5 percent per client= 0.2532
# median lr with top 5 percent per client= 0.3
# mean momentum with top 5 percent per client= 0.6719999999999999
# median momentum with top 5 percent per client= 0.75
# 1.0
# clustering/experiments/extended_data/svhn_cropped_qty_skew_1.0_10clients.csv
# mean lr= 0.15142857142857144
# median lr= 0.07
# trimmed mean with beta=0.1 lr= 0.12553571428571428
# mean momentum= 0.55
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.56875
# mean lr with top 5 percent per client= 0.26260000000000006
# median lr with top 5 percent per client= 0.3
# mean momentum with top 5 percent per client= 0.6829999999999999
# median momentum with top 5 percent per client= 0.9
# 2.0
# clustering/experiments/extended_data/svhn_cropped_qty_skew_2.0_10clients.csv
# mean lr= 0.15142857142857144
# median lr= 0.07
# trimmed mean with beta=0.1 lr= 0.12553571428571428
# mean momentum= 0.55
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.56875
# mean lr with top 5 percent per client= 0.276
# median lr with top 5 percent per client= 0.3
# mean momentum with top 5 percent per client= 0.7060000000000001
# median momentum with top 5 percent per client= 0.9
# 0.1
# clustering/experiments/extended_data/svhn_cropped_qty_skew_0.1_20clients.csv
# mean lr= 0.15142857142857144
# median lr= 0.07
# trimmed mean with beta=0.1 lr= 0.12553571428571428
# mean momentum= 0.55
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.56875
# mean lr with top 5 percent per client= 0.24050000000000002
# median lr with top 5 percent per client= 0.2
# mean momentum with top 5 percent per client= 0.6370000000000001
# median momentum with top 5 percent per client= 0.75
# 0.4
# clustering/experiments/extended_data/svhn_cropped_qty_skew_0.4_20clients.csv
# mean lr= 0.15142857142857144
# median lr= 0.07
# trimmed mean with beta=0.1 lr= 0.12553571428571428
# mean momentum= 0.55
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.56875
# mean lr with top 5 percent per client= 0.2455
# median lr with top 5 percent per client= 0.3
# mean momentum with top 5 percent per client= 0.7010000000000001
# median momentum with top 5 percent per client= 0.9
# 1.0
# clustering/experiments/extended_data/svhn_cropped_qty_skew_1.0_20clients.csv
# mean lr= 0.15142857142857144
# median lr= 0.07
# trimmed mean with beta=0.1 lr= 0.12553571428571428
# mean momentum= 0.55
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.56875
# mean lr with top 5 percent per client= 0.26700000000000007
# median lr with top 5 percent per client= 0.3
# mean momentum with top 5 percent per client= 0.7015000000000002
# median momentum with top 5 percent per client= 0.9
# 2.0
# clustering/experiments/extended_data/svhn_cropped_qty_skew_2.0_20clients.csv
# mean lr= 0.15142857142857144
# median lr= 0.07
# trimmed mean with beta=0.1 lr= 0.12553571428571428
# mean momentum= 0.55
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.56875
# mean lr with top 5 percent per client= 0.2572
# median lr with top 5 percent per client= 0.3
# mean momentum with top 5 percent per client= 0.7150000000000002
# median momentum with top 5 percent per client= 0.9
# 0.1
# clustering/experiments/extended_data/svhn_cropped_label_skew_0.1_10clients.csv
# mean lr= 0.14375
# median lr= 0.08
# trimmed mean with beta=0.1 lr= 0.1159375
# mean momentum= 0.55
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.56875
# mean lr with top 5 percent per client= 0.22550000000000003
# median lr with top 5 percent per client= 0.095
# mean momentum with top 5 percent per client= 0.6925
# median momentum with top 5 percent per client= 0.9
# 1.0
# clustering/experiments/extended_data/svhn_cropped_label_skew_1.0_10clients.csv
# mean lr= 0.14375
# median lr= 0.08
# trimmed mean with beta=0.1 lr= 0.1159375
# mean momentum= 0.55
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.56875
# mean lr with top 5 percent per client= 0.24775
# median lr with top 5 percent per client= 0.1
# mean momentum with top 5 percent per client= 0.72875
# median momentum with top 5 percent per client= 0.9
# 5.0
# clustering/experiments/extended_data/svhn_cropped_label_skew_5.0_10clients.csv
# mean lr= 0.14375
# median lr= 0.08
# trimmed mean with beta=0.1 lr= 0.1159375
# mean momentum= 0.55
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.56875
# mean lr with top 5 percent per client= 0.21425
# median lr with top 5 percent per client= 0.09
# mean momentum with top 5 percent per client= 0.745
# median momentum with top 5 percent per client= 0.9
# 0.1
# clustering/experiments/extended_data/svhn_cropped_label_skew_0.1_20clients.csv
# mean lr= 0.14375000000000002
# median lr= 0.08
# trimmed mean with beta=0.1 lr= 0.1159375
# mean momentum= 0.55
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.56875
# mean lr with top 5 percent per client= 0.22350000000000003
# median lr with top 5 percent per client= 0.1
# mean momentum with top 5 percent per client= 0.655
# median momentum with top 5 percent per client= 0.6
# 1.0
# clustering/experiments/extended_data/svhn_cropped_label_skew_1.0_20clients.csv
# mean lr= 0.14375
# median lr= 0.08
# trimmed mean with beta=0.1 lr= 0.1159375
# mean momentum= 0.55
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.56875
# mean lr with top 5 percent per client= 0.21812500000000004
# median lr with top 5 percent per client= 0.1
# mean momentum with top 5 percent per client= 0.8068750000000001
# median momentum with top 5 percent per client= 0.9
# 5.0
# clustering/experiments/extended_data/svhn_cropped_label_skew_5.0_20clients.csv
# mean lr= 0.14375
# median lr= 0.08
# trimmed mean with beta=0.1 lr= 0.1159375
# mean momentum= 0.55
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.56875
# mean lr with top 5 percent per client= 0.21575000000000005
# median lr with top 5 percent per client= 0.1
# mean momentum with top 5 percent per client= 0.806875
# median momentum with top 5 percent per client= 0.9
# 0.1
# clustering/experiments/extended_data/svhn_cropped_feature_skew_0.1_10clients.csv
# mean lr= 0.14375000000000002
# median lr= 0.08
# trimmed mean with beta=0.1 lr= 0.1159375
# mean momentum= 0.55
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.56875
# mean lr with top 5 percent per client= 0.23425
# median lr with top 5 percent per client= 0.1
# mean momentum with top 5 percent per client= 0.7237500000000001
# median momentum with top 5 percent per client= 0.9
# 0.02
# clustering/experiments/extended_data/svhn_cropped_feature_skew_0.02_10clients.csv
# mean lr= 0.14375
# median lr= 0.08
# trimmed mean with beta=0.1 lr= 0.1159375
# mean momentum= 0.55
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.56875
# mean lr with top 5 percent per client= 0.266
# median lr with top 5 percent per client= 0.3
# mean momentum with top 5 percent per client= 0.7074999999999999
# median momentum with top 5 percent per client= 0.6
# 0.1
# clustering/experiments/extended_data/svhn_cropped_feature_skew_0.1_20clients.csv
# mean lr= 0.14375
# median lr= 0.08
# trimmed mean with beta=0.1 lr= 0.1159375
# mean momentum= 0.55
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.56875
# mean lr with top 5 percent per client= 0.183875
# median lr with top 5 percent per client= 0.1
# mean momentum with top 5 percent per client= 0.825
# median momentum with top 5 percent per client= 0.9
# 0.02
# clustering/experiments/extended_data/svhn_cropped_feature_skew_0.02_20clients.csv
# mean lr= 0.14375
# median lr= 0.08
# trimmed mean with beta=0.1 lr= 0.1159375
# mean momentum= 0.55
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.56875
# mean lr with top 5 percent per client= 0.20837500000000003
# median lr with top 5 percent per client= 0.1
# mean momentum with top 5 percent per client= 0.805625
# median momentum with top 5 percent per client= 0.9
# 0.1
# clustering/experiments/extended_data/emnist_qty_skew_0.1_10clients.csv
# mean lr= 0.16499999999999998
# median lr= 0.07500000000000001
# trimmed mean with beta=0.1 lr= 0.1425
# mean momentum= 0.45
# median momentum= 0.44999999999999996
# trimmed mean with beta=0.1 momentum= 0.45
# mean lr with top 5 percent per client= 0.386
# median lr with top 5 percent per client= 0.5
# mean momentum with top 5 percent per client= 0.8400000000000001
# median momentum with top 5 percent per client= 0.9
# 0.4
# clustering/experiments/extended_data/emnist_qty_skew_0.4_10clients.csv
# mean lr= 0.165
# median lr= 0.07500000000000001
# trimmed mean with beta=0.1 lr= 0.1425
# mean momentum= 0.44999999999999996
# median momentum= 0.44999999999999996
# trimmed mean with beta=0.1 momentum= 0.45
# mean lr with top 5 percent per client= 0.48
# median lr with top 5 percent per client= 0.5
# mean momentum with top 5 percent per client= 0.885
# median momentum with top 5 percent per client= 0.9
# 1.0
# clustering/experiments/extended_data/emnist_qty_skew_1.0_10clients.csv
# mean lr= 0.165
# median lr= 0.07500000000000001
# trimmed mean with beta=0.1 lr= 0.1425
# mean momentum= 0.44999999999999996
# median momentum= 0.44999999999999996
# trimmed mean with beta=0.1 momentum= 0.45
# mean lr with top 5 percent per client= 0.5
# median lr with top 5 percent per client= 0.5
# mean momentum with top 5 percent per client= 0.8999999999999998
# median momentum with top 5 percent per client= 0.9
# 2.0
# clustering/experiments/extended_data/emnist_qty_skew_2.0_10clients.csv
# mean lr= 0.165
# median lr= 0.07500000000000001
# trimmed mean with beta=0.1 lr= 0.1425
# mean momentum= 0.45
# median momentum= 0.44999999999999996
# trimmed mean with beta=0.1 momentum= 0.45
# mean lr with top 5 percent per client= 0.5
# median lr with top 5 percent per client= 0.5
# mean momentum with top 5 percent per client= 0.8699999999999999
# median momentum with top 5 percent per client= 0.9
# 0.1
# clustering/experiments/extended_data/emnist_qty_skew_0.1_20clients.csv
# mean lr= 0.165
# median lr= 0.07500000000000001
# trimmed mean with beta=0.1 lr= 0.1425
# mean momentum= 0.45
# median momentum= 0.44999999999999996
# trimmed mean with beta=0.1 momentum= 0.45
# mean lr with top 5 percent per client= 0.43525
# median lr with top 5 percent per client= 0.5
# mean momentum with top 5 percent per client= 0.8399999999999999
# median momentum with top 5 percent per client= 0.9
# 0.4
# clustering/experiments/extended_data/emnist_qty_skew_0.4_20clients.csv
# mean lr= 0.165
# median lr= 0.07500000000000001
# trimmed mean with beta=0.1 lr= 0.1425
# mean momentum= 0.45
# median momentum= 0.44999999999999996
# trimmed mean with beta=0.1 momentum= 0.45
# mean lr with top 5 percent per client= 0.43425
# median lr with top 5 percent per client= 0.5
# mean momentum with top 5 percent per client= 0.7725
# median momentum with top 5 percent per client= 0.9
# 1.0
# clustering/experiments/extended_data/emnist_qty_skew_1.0_20clients.csv
# mean lr= 0.16500000000000004
# median lr= 0.07500000000000001
# trimmed mean with beta=0.1 lr= 0.1425
# mean momentum= 0.45
# median momentum= 0.44999999999999996
# trimmed mean with beta=0.1 momentum= 0.45
# mean lr with top 5 percent per client= 0.5
# median lr with top 5 percent per client= 0.5
# mean momentum with top 5 percent per client= 0.885
# median momentum with top 5 percent per client= 0.9
# 2.0
# clustering/experiments/extended_data/emnist_qty_skew_2.0_20clients.csv
# mean lr= 0.165
# median lr= 0.07500000000000001
# trimmed mean with beta=0.1 lr= 0.1425
# mean momentum= 0.45
# median momentum= 0.44999999999999996
# trimmed mean with beta=0.1 momentum= 0.45
# mean lr with top 5 percent per client= 0.49000000000000005
# median lr with top 5 percent per client= 0.5
# mean momentum with top 5 percent per client= 0.885
# median momentum with top 5 percent per client= 0.9
# 0.1
# clustering/experiments/extended_data/emnist_label_skew_0.1_10clients.csv
# mean lr= 0.14375
# median lr= 0.08
# trimmed mean with beta=0.1 lr= 0.1159375
# mean momentum= 0.55
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.56875
# mean lr with top 5 percent per client= 0.40449999999999997
# median lr with top 5 percent per client= 0.5
# mean momentum with top 5 percent per client= 0.9237500000000001
# median momentum with top 5 percent per client= 0.95
# 1.0
# clustering/experiments/extended_data/emnist_label_skew_1.0_10clients.csv
# mean lr= 0.14375
# median lr= 0.08
# trimmed mean with beta=0.1 lr= 0.1159375
# mean momentum= 0.55
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.56875
# mean lr with top 5 percent per client= 0.39475
# median lr with top 5 percent per client= 0.5
# mean momentum with top 5 percent per client= 0.93125
# median momentum with top 5 percent per client= 0.95
# 5.0
# clustering/experiments/extended_data/emnist_label_skew_5.0_10clients.csv
# mean lr= 0.14375000000000002
# median lr= 0.08
# trimmed mean with beta=0.1 lr= 0.1159375
# mean momentum= 0.5499999999999999
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.56875
# mean lr with top 5 percent per client= 0.4
# median lr with top 5 percent per client= 0.4
# mean momentum with top 5 percent per client= 0.93
# median momentum with top 5 percent per client= 0.95
# 0.1
# clustering/experiments/extended_data/emnist_label_skew_0.1_20clients.csv
# mean lr= 0.14375
# median lr= 0.08
# trimmed mean with beta=0.1 lr= 0.1159375
# mean momentum= 0.55
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.56875
# mean lr with top 5 percent per client= 0.38125
# median lr with top 5 percent per client= 0.5
# mean momentum with top 5 percent per client= 0.92125
# median momentum with top 5 percent per client= 0.95
# 1.0
# clustering/experiments/extended_data/emnist_label_skew_1.0_20clients.csv
# mean lr= 0.14375
# median lr= 0.08
# trimmed mean with beta=0.1 lr= 0.1159375
# mean momentum= 0.55
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.56875
# mean lr with top 5 percent per client= 0.41749999999999987
# median lr with top 5 percent per client= 0.5
# mean momentum with top 5 percent per client= 0.9356249999999999
# median momentum with top 5 percent per client= 0.95
# 5.0
# clustering/experiments/extended_data/emnist_label_skew_5.0_20clients.csv
# mean lr= 0.14375
# median lr= 0.08
# trimmed mean with beta=0.1 lr= 0.1159375
# mean momentum= 0.55
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.56875
# mean lr with top 5 percent per client= 0.43
# median lr with top 5 percent per client= 0.5
# mean momentum with top 5 percent per client= 0.9337499999999999
# median momentum with top 5 percent per client= 0.95
# 0.1
# clustering/experiments/extended_data/emnist_feature_skew_0.1_10clients.csv
# mean lr= 0.14375
# median lr= 0.08
# trimmed mean with beta=0.1 lr= 0.1159375
# mean momentum= 0.55
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.56875
# mean lr with top 5 percent per client= 0.4
# median lr with top 5 percent per client= 0.4
# mean momentum with top 5 percent per client= 0.9262499999999999
# median momentum with top 5 percent per client= 0.95
# 0.02
# clustering/experiments/extended_data/emnist_feature_skew_0.02_10clients.csv
# mean lr= 0.14375
# median lr= 0.08
# trimmed mean with beta=0.1 lr= 0.1159375
# mean momentum= 0.55
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.56875
# mean lr with top 5 percent per client= 0.41500000000000004
# median lr with top 5 percent per client= 0.5
# mean momentum with top 5 percent per client= 0.93625
# median momentum with top 5 percent per client= 0.95
# 0.1
# clustering/experiments/extended_data/emnist_feature_skew_0.1_20clients.csv
# mean lr= 0.14375
# median lr= 0.08
# trimmed mean with beta=0.1 lr= 0.1159375
# mean momentum= 0.55
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.56875
# mean lr with top 5 percent per client= 0.43249999999999994
# median lr with top 5 percent per client= 0.5
# mean momentum with top 5 percent per client= 0.9337500000000001
# median momentum with top 5 percent per client= 0.95
# 0.02
# clustering/experiments/extended_data/emnist_feature_skew_0.02_20clients.csv
# mean lr= 0.14375
# median lr= 0.08
# trimmed mean with beta=0.1 lr= 0.1159375
# mean momentum= 0.55
# median momentum= 0.6
# trimmed mean with beta=0.1 momentum= 0.56875
# mean lr with top 5 percent per client= 0.42499999999999993
# median lr with top 5 percent per client= 0.5
# mean momentum with top 5 percent per client= 0.934375
# median momentum with top 5 percent per client= 0.95

# %%
# add DBSCAN values 
plotdf.loc[len(plotdf)] = ['mnist', 'label_skew', 1.0, 10, 0.3,  0.9, 'DBSCAN']  
plotdf.loc[len(plotdf)] = ['mnist', 'label_skew', 1.0, 20, 0.5,  0.6, 'DBSCAN']
plotdf.loc[len(plotdf)] = ['emnist', 'label_skew', 1.0, 10, 0.5,  0.9, 'DBSCAN']  
plotdf.loc[len(plotdf)] = ['emnist', 'label_skew', 1.0, 20, 0.5,  0.6, 'DBSCAN']
plotdf.loc[len(plotdf)] = ['svhn_cropped', 'label_skew', 1.0, 10, 0.5,  0.3, 'DBSCAN']  
plotdf.loc[len(plotdf)] = ['svhn_cropped', 'label_skew', 1.0, 20, 0.5,  0.6, 'DBSCAN']
plotdf.loc[len(plotdf)] = ['cifar10', 'label_skew', 1.0, 10, 0.5,  0.6, 'DBSCAN']  
plotdf.loc[len(plotdf)] = ['cifar10', 'label_skew', 1.0, 20, 0.5,  0.6, 'DBSCAN']

plotdf.loc[len(plotdf)] = ['mnist', 'feature_skew', 0.02, 10,0.5,  0.6, 'DBSCAN']  
plotdf.loc[len(plotdf)] = ['mnist', 'feature_skew', 0.02, 20, 0.5,  0.6, 'DBSCAN']
plotdf.loc[len(plotdf)] = ['emnist', 'feature_skew', 0.02, 10, 0.5,  0.9, 'DBSCAN']  
plotdf.loc[len(plotdf)] = ['emnist', 'feature_skew', 0.02, 20, 0.5,  0.9, 'DBSCAN']
plotdf.loc[len(plotdf)] = ['svhn_cropped', 'feature_skew', 0.02, 10, 0.5,  0.3, 'DBSCAN']  
plotdf.loc[len(plotdf)] = ['svhn_cropped', 'feature_skew', 0.02, 20, 0.5,  0.6, 'DBSCAN']
plotdf.loc[len(plotdf)] = ['cifar10', 'feature_skew', 0.02, 10, 0.5,  0.6, 'DBSCAN']  
plotdf.loc[len(plotdf)] = ['cifar10', 'feature_skew', 0.02, 20, 0.5,  0.6, 'DBSCAN']

plotdf.loc[len(plotdf)] = ['mnist', 'qty_skew', 2.0, 10,0.5,  0.6, 'DBSCAN']  
plotdf.loc[len(plotdf)] = ['mnist', 'qty_skew', 2.0, 20, 0.5,  0.6, 'DBSCAN']
plotdf.loc[len(plotdf)] = ['emnist', 'qty_skew', 2.0, 10, 0.5,  0.6, 'DBSCAN']  
plotdf.loc[len(plotdf)] = ['emnist', 'qty_skew', 2.0, 20, 0.5,  0.6, 'DBSCAN']
plotdf.loc[len(plotdf)] = ['svhn_cropped', 'qty_skew', 2.0, 10, 0.5,  0.6, 'DBSCAN']  
plotdf.loc[len(plotdf)] = ['svhn_cropped', 'qty_skew', 2.0, 20, 0.5,  0.6, 'DBSCAN']
plotdf.loc[len(plotdf)] = ['cifar10', 'qty_skew', 2.0, 10, 0.5,  0.6, 'DBSCAN']  
plotdf.loc[len(plotdf)] = ['cifar10', 'qty_skew', 2.0, 20, 0.5,  0.3, 'DBSCAN']

# %%
import sys
sys.path.append('../../')

import json
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Set the font size for x tick labels
plt.rc('xtick', labelsize=30)
# Set the font size for y tick labels
plt.rc('ytick', labelsize=30)
from matplotlib.lines import Line2D

columns=['dataset', 'skew_type', 'skew', 'nr_clients', 'lr',  'mom', 'bs', 'experiment_type']   

def plot_barplot1(df, hue=[], title='', saveTitle='', saveFig=False, savePath='measurement_results/',param='', param_ann='',skew_type='',skew=''):
    sns.set_theme()
    plt.figure(figsize=(23, 8))

    ax = sns.barplot(y=param_ann, x="dataset", hue="experiment_type",
                hue_order=hue,
                data=df)
    
    sns.set(font_scale=0.8)
    for p in ax.patches:
        ax.annotate(format(p.get_height(), '.1f'), (p.get_x() + p.get_width() / 2., p.get_height()), 
        ha = 'center', va = 'center', xytext = (0, 15), textcoords = 'offset points', fontsize='20')
    
    plt.legend(loc='lower left')
    plt.setp(ax.get_legend().get_texts(), fontsize='20')
    ax.xaxis.label.set_fontsize(24)
    ax.yaxis.label.set_fontsize(24)
    plt.title(title, fontsize='24')
    plt.ylabel(param)
    plt.xlabel("Dataset")
    plt.tight_layout()

    if saveFig:
        print(param+'_'+skew_type+skew+".pdf")
        plt.savefig(param+'_'+skew_type+skew+".pdf")
        
    plt.show()
    plt.close()

# %%
#select some experiments: 
#label skew with 1.0

plotdfL = plotdf.loc[(plotdf['skew_type'] == 'label_skew') & (plotdf['skew'] == 1.0)& (plotdf['nr_clients'] == 20)]

hue = ['Ground Truth','DBSCAN', 'mean', 'median', 'trimmed mean', 'mean of the top 5%','median of the top 5%']
plot_barplot1(plotdfL, title="Measurements", savePath='measurement_results/', saveFig=True, hue=hue,param="Learning Rate",param_ann="lr", skew_type='label_skew',skew='1.0')


hue = ['Ground Truth','DBSCAN', 'mean', 'median', 'trimmed mean', 'mean of the top 5%','median of the top 5%']
plot_barplot1(plotdfL, title="Measurements", savePath='measurement_results/', saveFig=True, hue=hue,param="Momentum",param_ann="mom", skew_type='label_skew',skew='1.0')
# Out:
# Learning Rate_label_skew1.0.pdf
# Momentum_label_skew1.0.pdf

# %%
#select some experiments: 
#feature skew with 0.02

plotdfL = plotdf.loc[(plotdf['skew_type'] == 'feature_skew') & (plotdf['skew'] == 0.02)& (plotdf['nr_clients'] == 20)]

hue = ['Ground Truth','DBSCAN', 'mean', 'median', 'trimmed mean', 'mean of the top 5%','median of the top 5%']
plot_barplot1(plotdfL, title="Measurements", savePath='', saveFig=True, hue=hue,param="Learning Rate",param_ann="lr", skew_type='feature_skew',skew='0.02')

hue = ['Ground Truth','DBSCAN', 'mean', 'median', 'trimmed mean', 'mean of the top 5%','median of the top 5%']
plot_barplot1(plotdfL, title="Measurements", savePath='', saveFig=True, hue=hue,param="Momentum",param_ann="mom", skew_type='feature_skew',skew='0.02')
# Out:
# Learning Rate_feature_skew0.02.pdf
# Momentum_feature_skew0.02.pdf

# %%
# Out:
# Learning Rate.pdf

# %%
#select some experiments: 
#qty skew with 2.0

plotdfL = plotdf.loc[(plotdf['skew_type'] == 'qty_skew') & (plotdf['skew'] == 2.0)& (plotdf['nr_clients'] == 20)]

hue = ['Ground Truth','DBSCAN', 'mean', 'median', 'trimmed mean', 'mean of the top 5%','median of the top 5%']
plot_barplot1(plotdfL, title="Measurements", savePath='', saveFig=True, hue=hue,param="Learning Rate",param_ann="lr", skew_type='qty_skew',skew='2.0')
plot_barplot1(plotdfL, title="Measurements", savePath='', saveFig=True, hue=hue,param="Momentum",param_ann="mom", skew_type='qty_skew',skew='2.0')
# Out:
# Learning Rate_qty_skew2.0.pdf

# %%
# Out:
#           dataset skew_type  skew  nr_clients        lr      mom  \
# 0           mnist  qty_skew   0.1          10  0.300000  0.00000
# 1           mnist  qty_skew   0.1          10  0.151429  0.55000
# 2           mnist  qty_skew   0.1          10  0.125536  0.56875
# 3           mnist  qty_skew   0.1          10  0.070000  0.60000
# 4           mnist  qty_skew   0.1          10  0.328000  0.81300
# ..            ...       ...   ...         ...       ...      ...
# 451        emnist  qty_skew   2.0          20  0.500000  0.60000
# 452  svhn_cropped  qty_skew   2.0          10  0.500000  0.60000
# 453  svhn_cropped  qty_skew   2.0          20  0.500000  0.60000
# 454       cifar10  qty_skew   2.0          10  0.500000  0.60000
# 455       cifar10  qty_skew   2.0          20  0.500000  0.30000
#
#         experiment_type
# 0          Ground Truth
# 1                  mean
# 2          trimmed mean
# 3                median
# 4    mean of the top 5%
# ..                  ...
# 451              DBSCAN
# 452              DBSCAN
# 453              DBSCAN
# 454              DBSCAN
# 455              DBSCAN
#
# [456 rows x 7 columns]
